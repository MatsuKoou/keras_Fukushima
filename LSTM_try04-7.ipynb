# %% [markdown]
# <a href="https://colab.research.google.com/github/SeiichiroFukushima/keras/blob/master/LSTM_try04-7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 複数の実験データから大規模なデータセットを準備する
#
# ＜時系列データフレームの準備＞
# *   指定されたパス内のフォルダ構造も解析してパス付のCSVファイルのリストを作成する。
# *   CSVファイルリストでループを回す。
# *   上記ループ内でCSVファイルをロードする。
# *   ロードしたデータをデータフレーム化して、タイムスタンプをカラムに追加する。
# *   ロードしたCSVファイルのラベルリストを準備する。
# *   不要なインデックスをラベルリストを準備する。
# *   データフレームから不要なカラムを除外する。
# *   不要なデータ行（例えば、データNo.、カメラ時間、カメラ時間がゼロでスパッタ発生量がゼロの行、等）を除外する。
# *   さらに指定された溶接開始時間と溶接終了時間を除いたメイン溶接のデータ行だけにする。
# *   リスト項目
# *   リスト項目
#
#
# ＜時系列データフレームのダウンサンプリングと正規化＞
# *   リスト項目
# *   リスト項目
# *   リスト項目

# %%
import os
import pandas as pd
from datetime import timedelta
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Googleドライブのマウント

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## フォルダパス内のCSVファイルのリストを作成する

# %%
folder_path ='/content/drive/MyDrive/Colab Notebooks/dataset/welding_data'

# フォルダパス内のCSVファイルのリストを作成する
csv_files = []
for root, dirs, files in os.walk(folder_path):
    for file in files:
        if file.endswith(".csv"):
            csv_files.append(os.path.join(root, file))

print(csv_files)
# Out:
# ['/content/drive/MyDrive/Colab Notebooks/dataset/welding_data/W12_MAGPlus/RENEW_No_6_WeldValue_20230519135939.csv', '/content/drive/MyDrive/Colab Notebooks/dataset/welding_data/W12_MAGPlus/RENEW_No_28_WeldValue_20230519140437.csv', '/content/drive/MyDrive/Colab Notebooks/dataset/welding_data/W12_MAGPlus/RENEW_No_56_WeldValue_20230519142414.csv', '/content/drive/MyDrive/Colab Notebooks/dataset/welding_data/W12_MAGPlus/RENEW_No_58_WeldValue_20230519143002.csv', '/content/drive/MyDrive/Colab Notebooks/dataset/welding_data/W12_MAGPlus/RENEW_No_61_WeldValue_20230519135607.csv', '/content/drive/MyDrive/Colab Notebooks/dataset/welding_data/W12_MAGPlus/RENEW_No_64_WeldValue_20230519143905.csv', '/content/drive/MyDrive/Colab Notebooks/dataset/welding_data/W12_MAGPlus/RENEW_No_83_WeldValue_20230519144417.csv', '/content/drive/MyDrive/Colab Notebooks/dataset/welding_data/W12_MAGPlus/RENEW_No_116_WeldValue_20230519145008.csv', '/content/drive/MyDrive/Colab Notebooks/dataset/welding_data/W12_MAGPlus/RENEW_No_127_WeldValue_20230519145625.csv', '/content/drive/MyDrive/Colab Notebooks/dataset/welding_data/W12_MAGPlus/RENEW_No_149_WeldValue_20230519150203.csv', '/content/drive/MyDrive/Colab Notebooks/dataset/welding_data/W12_MAGPlus/RENEW_No_204_WeldValue_20230519150605.csv', '/content/drive/MyDrive/Colab Notebooks/dataset/welding_data/W12_MAGPlus/RENEW_No_226_WeldValue_20230519153232.csv', '/content/drive/MyDrive/Colab Notebooks/dataset/welding_data/W12_MAGPlus/RENEW_No_232_WeldValue_20230519153924.csv', '/content/drive/MyDrive/Colab Notebooks/dataset/welding_data/W12_MAGPlus/RENEW_No_234_WeldValue_20230519154714.csv', '/content/drive/MyDrive/Colab Notebooks/dataset/welding_data/W12_MAGPlus/RENEW_No_239_WeldValue_20230519155144.csv', '/content/drive/MyDrive/Colab Notebooks/dataset/welding_data/W12_MAGPlus/RENEW_No_241_WeldValue_20230519155716.csv', '/content/drive/MyDrive/Colab Notebooks/dataset/welding_data/W12_MAGPlus/RENEW_No_242_WeldValue_20230519160240.csv', '/content/drive/MyDrive/Colab Notebooks/dataset/welding_data/W12_MAGPlus/RENEW_No_244_WeldValue_20230519161101.csv', '/content/drive/MyDrive/Colab Notebooks/dataset/welding_data/W12_MAGPlus/RENEW_No_249_WeldValue_20230519161615.csv', '/content/drive/MyDrive/Colab Notebooks/dataset/welding_data/W12_MAGPlus/RENEW_No_251_WeldValue_20230519162133.csv', '/content/drive/MyDrive/Colab Notebooks/dataset/welding_data/W12_MAGShrt/RENEW_No_6_WeldValue_20230530133812.csv', '/content/drive/MyDrive/Colab Notebooks/dataset/welding_data/W12_MAGShrt/RENEW_No_28_WeldValue_20230530134404.csv', '/content/drive/MyDrive/Colab Notebooks/dataset/welding_data/W12_MAGShrt/RENEW_No_56_WeldValue_20230531085018.csv', '/content/drive/MyDrive/Colab Notebooks/dataset/welding_data/W12_MAGShrt/RENEW_No_58_WeldValue_20230530135640.csv', '/content/drive/MyDrive/Colab Notebooks/dataset/welding_data/W12_MAGShrt/RENEW_No_61_WeldValue_20230530140328.csv', '/content/drive/MyDrive/Colab Notebooks/dataset/welding_data/W12_MAGShrt/RENEW_No_64_WeldValue_20230530141332.csv', '/content/drive/MyDrive/Colab Notebooks/dataset/welding_data/W12_MAGShrt/RENEW_No_66_WeldValue_20230530142121.csv', '/content/drive/MyDrive/Colab Notebooks/dataset/welding_data/W12_MAGShrt/RENEW_No_94_WeldValue_20230530142553.csv', '/content/drive/MyDrive/Colab Notebooks/dataset/welding_data/W12_MAGShrt/RENEW_No_116_WeldValue_20230530143033.csv', '/content/drive/MyDrive/Colab Notebooks/dataset/welding_data/W12_MAGShrt/RENEW_No_127_WeldValue_20230530143616.csv', '/content/drive/MyDrive/Colab Notebooks/dataset/welding_data/W12_MAGShrt/RENEW_No_149_WeldValue_20230530144046.csv', '/content/drive/MyDrive/Colab Notebooks/dataset/welding_data/W12_MAGShrt/RENEW_No_204_WeldValue_20230530144546.csv', '/content/drive/MyDrive/Colab Notebooks/dataset/welding_data/W12_MAGShrt/RENEW_No_227_WeldValue_20230530145236.csv', '/content/drive/MyDrive/Colab Notebooks/dataset/welding_data/W12_MAGShrt/RENEW_No_246_WeldValue_20230530145755.csv', '/content/drive/MyDrive/Colab Notebook ...

# %% [markdown]
# # 溶接電源特徴量及びスパッタ発生量データのフォーマット
# >   index データ名称
# *   	0   No.
# *     1	  ｶﾒﾗ時間
# *     2	  ｽﾊﾟｯﾀ量
# *     3	  FB電流
# *   	4	  FB電圧
# *   	5	  ｱｰｸ切れ発生時間
# *   	6	  短絡時間
# *   	7	  ｱｰｸ時間
# *   	8   短絡回数
# *   	9	  ﾊﾟﾙｽ回数
# *   	10	ﾈｯｷﾝｸﾞ失敗回数
# *   	11	ﾈｯｷﾝｸﾞ時間
# *   	12	ｱｰｸ期間ﾋﾟｰｸ電圧
# *   	13	ｱｰｸ期間ﾋﾟｰｸ電流
# *   	14	短絡開放電流
# *   	15	短絡移行前ｱｰｸ電流
# *   	16	微小短絡回数
# *   	17	微小短絡発生前ｱｰｸ電流
# *   	18	異常短絡開放発生回数
# *   	19	ﾋﾟｰｸ短絡回数
# *   	20	ﾊﾟﾙｽﾍﾞｰｽ時燃え上がり発生回数
# *   	21	電流補償継続時間
# *   	22	1周期毎の電流補正量
# *   	23	1周期毎の電圧補正量
# *   	24	1周期毎の時間補正量
# *   	25	1周期毎の送給速度補正量
# *   	26	予備

# %%
# 溶接電源特徴量及びスパッタ発生量データのフォーマットを参考にCSVファイルのラベルリストを準備
label_list = ['No.','CameraTime','spatter:N','FBcurr','FBvolt','ArcCut:T','Shrt:T','Arc:T','Shrt:N','Plus:N','NeckMis:N','Neck:T','Arc-Peak:V','Arc-Peak:I','ShrtOpn:I','preShrt-Arc:I','microShrt:N','microShort-ArcI','Abnrml_ShrtOpn:N','Peak-Shrt:N','PlusBase_brnbk:N','currI_kep:T','1cyc-corrI','1cyc_corrV','1cyc-corrT','1cyc-corrWFS','reserve']

# ****** 溶接電源特徴量及びスパッタ発生量データの不要なデータ列の除外 ******
#     非特徴量データを除外
#     Name:'No.','CameraTime'
#
#     'FBcurr','FBvolt'のうち'FBcurr'だけ除外。
#     Name:'FBcurr'
#
#     ＣＯ２短絡、ＭＡＧ短絡、ＭＡＧパルスの時系列データから共通してゼロ値のデータのものを除外。
#     Name:'ArcCut:T', 'Abnrml_ShrtOpn:N', '1cyc_corrV','1cyc-corrWFS','reserve'
# まとめると、

# 不要な時系列データのラベルリスト
# ＣＯ２短絡、ＭＡＧ短絡、ＭＡＧパルスの時系列データから共通してゼロ値のデータのものを除外。（ＡＮＤ条件）
#unwanted_columns = ['No.','CameraTime','FBcurr','ArcCut:T','Abnrml_ShrtOpn:N','1cyc_corrV','1cyc-corrWFS','reserve']
# ＣＯ２短絡、ＭＡＧ短絡、ＭＡＧパルスのいづれか時系列データでゼロ値のデータのものを除外。（ＯＲ条件）
unwanted_columns = ['No.','CameraTime','ArcCut:T','NeckMis:N','Neck:T','microShrt:N','microShort-ArcI','Abnrml_ShrtOpn:N','Peak-Shrt:N', 'currI_kep:T', '1cyc_corrV','1cyc-corrWFS','reserve']

# %%
# CSVファイルをロードしてデータフレーム化する
data = pd.read_csv(csv_files[1]).values

# ndarrayをデータフレームに変換
df = pd.DataFrame(data=data, columns=label_list)

# タイムスタンプの範囲を生成
time_index = pd.date_range(start='2023-05-28 00:00:00', periods=len(df), freq='500us')
# タイムスタンプをデータフレームのインデックスとして設定
df = df.set_index(time_index)

# %%
df
# Out:
#                              No.  CameraTime  spatter:N  FBcurr  FBvolt  \
# 2023-05-28 00:00:00.000000     1      413000          1     798     550
# 2023-05-28 00:00:00.000500     2      413500          0     835     570
# 2023-05-28 00:00:00.001000     3      414000          0     828     562
# 2023-05-28 00:00:00.001500     4      414500          0     285     420
# 2023-05-28 00:00:00.002000     5      415000          1     153     381
# ...                          ...         ...        ...     ...     ...
# 2023-05-28 00:00:04.997000  9995           0          0      49     335
# 2023-05-28 00:00:04.997500  9996           0          0      49     333
# 2023-05-28 00:00:04.998000  9997           0          0     418     477
# 2023-05-28 00:00:04.998500  9998           0          0     811     544
# 2023-05-28 00:00:04.999000  9999           0          0     839     557
#
#                             ArcCut:T  Shrt:T  Arc:T  Shrt:N  Plus:N  ...  \
# 2023-05-28 00:00:00.000000         0       0     25       0       0  ...
# 2023-05-28 00:00:00.000500         0       0     25       0       0  ...
# 2023-05-28 00:00:00.001000         0       0     25       0       0  ...
# 2023-05-28 00:00:00.001500         0       0     25       0       0  ...
# 2023-05-28 00:00:00.002000         0       0     25       0       0  ...
# ...                              ...     ...    ...     ...     ...  ...
# 2023-05-28 00:00:04.997000         0       0     25       0       0  ...
# 2023-05-28 00:00:04.997500         0       0     25       0       1  ...
# 2023-05-28 00:00:04.998000         0       0     25       0       0  ...
# 2023-05-28 00:00:04.998500         0       0     25       0       0  ...
# 2023-05-28 00:00:04.999000         0       0     25       0       0  ...
#
#                             microShort-ArcI  Abnrml_ShrtOpn:N  Peak-Shrt:N  \
# 2023-05-28 00:00:00.000000                0                 0            0
# 2023-05-28 00:00:00.000500                0                 0            0
# 2023-05-28 00:00:00.001000                0                 0            0
# 2023-05-28 00:00:00.001500                0                 0            0
# 2023-05-28 00:00:00.002000                0                 0            0
# ...                                     ...               ...          ...
# 2023-05-28 00:00:04.997000                0                 0            0
# 2023-05-28 00:00:04.997500                0                 0            0
# 2023-05-28 00:00:04.998000                0                 0            0
# 2023-05-28 00:00:04.998500                0                 0            0
# 2023-05-28 00:00:04.999000                0                 0            0
#
#                             PlusBase_brnbk:N  currI_kep:T  1cyc-corrI  \
# 2023-05-28 00:00:00.000000                 0            0           0
# 2023-05-28 00:00:00.000500                 0            0           0
# 2023-05-28 00:00:00.001000                 0            0           0
# 2023-05-28 00:00:00.001500                 0            0           0
# 2023-05-28 00:00:00.002000                 0            0           0
# ...                                      ...          ...         ...
# 2023-05-28 00:00:04.997000                 0            0           0
# 2023-05-28 00:00:04.997500                 0            0           0
# 2023-05-28 00:00:04.998000                 0            0           0
# 2023-05-28 00:00:04.998500                 0            0           0
# 2023-05-28 00:00:04.999000                 0            0           0
#
#                             1cyc_corrV  1cyc-corrT  1cyc-corrWFS  reserve
# 2023-05-28 00:00:00.000000           0           0             0        0
# 2023-05-28 00:00:00.000500           0           0             0        0
# 2023-05-28 00:00:00.001000           0           0             0        0
# 2023-05-28 00:00:00.001500           0           0             0        0
# 2023-05-28 00:00:00.002000           0           0             0        0
# ...                                ...         ...           ...      ...
# 2023-05-28 00:00:04.997000           0           0             0        0
# 2023-05-28 00:00:04.997500           0          -1             0        0
# 2023-05-28 00:00:04.998000           0           0             0        0
# 2023-05-28 00:00:04.998500           0           0             0        0
# 2023-05-28 00:00:04.999000           0           0             0        0
#
# [9999 rows x 27 columns]

# %%
# データセットのデータフレームを作成する
dataset = pd.DataFrame()

# CSVファイルリストでループを回す
for csv_file in csv_files:
    # CSVファイルをロードしてデータフレーム化する
    data = pd.read_csv(csv_file).values

    # ndarrayをデータフレームに変換
    df = pd.DataFrame(data=data, columns=label_list)

    # タイムスタンプの範囲を生成
    time_index = pd.date_range(start='2023-05-28 00:00:00', periods=len(df), freq='500us')
    # タイムスタンプをデータフレームのインデックスとして設定
    df = df.set_index(time_index)

    # 不要なデータ行を除外する
    # カメラ時間（'CameraTime'）がゼロでスパッタ発生量（'spatter:N'）がゼロの行を除外する
    df = df[(df["CameraTime"] != 0) & (df["spatter:N"] != 0)]

    # 不要なカラムを除外する
    df = df.drop(columns=unwanted_columns)

    # 指定された溶接開始時間（最初の1秒間）と溶接終了時間（最後の1秒間）を除外する
    start_index = df.index[0] + timedelta(seconds=1)
    end_index = df.index[-1] - timedelta(seconds=1)
    filter_condition = (df.index >= start_index) & (df.index <= end_index)
    filtered_df = df[filter_condition]

    # 100msごとにダウンサンプリング
    df_resampled = filtered_df.resample('50ms').sum()

    # データセットにデータフレームを追加する
    dataset = pd.concat([dataset, df_resampled], ignore_index=True)

# データセットのデータフレームを表示する
print(dataset)
# Out:
#       spatter:N  FBcurr  FBvolt  Shrt:T  Arc:T  Shrt:N  Plus:N  Arc-Peak:V  \
# 0            32    7079   10425      28    597       3       3        2009
# 1            14    3813    4947      21    329       3       2         508
# 2            14    2147    4094      64    261       0       2         505
# 3             6    2598    2517      16    134       1       1         500
# 4             9    3069    3372       4    196       0       0           0
# ...         ...     ...     ...     ...    ...     ...     ...         ...
# 3607         46   12743   13789    1276    727       1       0           0
# 3608         46   10059   13408     430    745       0       0           0
# 3609         43   10568   10856    1752    609       1       0         915
# 3610         69   14862   17561    1493    999       1       0         999
# 3611         55   16826   16386     386    862       0       0         970
#
#       Arc-Peak:I  ShrtOpn:I  preShrt-Arc:I  PlusBase_brnbk:N  1cyc-corrI  \
# 0           2797         96            312                 3          15
# 1            705        181            372                 1          22
# 2            719        189              0                 3          30
# 3            688          0            114                 0           0
# 4              0         69              0                 2           0
# ...          ...        ...            ...               ...         ...
# 3607           0       1944            828                 0         -92
# 3608           0        638              0                 0         -92
# 3609         883       1247            340                 0         -77
# 3610         917       1427            498                 0         -46
# 3611         874       2395            852                 0        -123
#
#       1cyc-corrT
# 0              5
# 1              5
# 2              6
# 3              1
# 4              0
# ...          ...
# 3607           0
# 3608           0
# 3609           0
# 3610           0
# 3611           0
#
# [3612 rows x 14 columns]

# %%
dataset
# Out:
#       spatter:N  FBcurr  FBvolt  Shrt:T  Arc:T  Shrt:N  Plus:N  Arc-Peak:V  \
# 0            32    7079   10425      28    597       3       3        2009
# 1            14    3813    4947      21    329       3       2         508
# 2            14    2147    4094      64    261       0       2         505
# 3             6    2598    2517      16    134       1       1         500
# 4             9    3069    3372       4    196       0       0           0
# ...         ...     ...     ...     ...    ...     ...     ...         ...
# 3607         46   12743   13789    1276    727       1       0           0
# 3608         46   10059   13408     430    745       0       0           0
# 3609         43   10568   10856    1752    609       1       0         915
# 3610         69   14862   17561    1493    999       1       0         999
# 3611         55   16826   16386     386    862       0       0         970
#
#       Arc-Peak:I  ShrtOpn:I  preShrt-Arc:I  PlusBase_brnbk:N  1cyc-corrI  \
# 0           2797         96            312                 3          15
# 1            705        181            372                 1          22
# 2            719        189              0                 3          30
# 3            688          0            114                 0           0
# 4              0         69              0                 2           0
# ...          ...        ...            ...               ...         ...
# 3607           0       1944            828                 0         -92
# 3608           0        638              0                 0         -92
# 3609         883       1247            340                 0         -77
# 3610         917       1427            498                 0         -46
# 3611         874       2395            852                 0        -123
#
#       1cyc-corrT
# 0              5
# 1              5
# 2              6
# 3              1
# 4              0
# ...          ...
# 3607           0
# 3608           0
# 3609           0
# 3610           0
# 3611           0
#
# [3612 rows x 14 columns]

# %% [markdown]
# # データセットの正規化

# %%
import IPython
import IPython.display
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

train_mean = dataset.mean()
train_std = dataset.std()

df_std = (dataset - train_mean) / train_std

dataset_std = df_std
#df_std = df
df_std = df_std.melt(var_name='Column', value_name='Normalized')
plt.figure(figsize=(12, 6))
ax = sns.violinplot(x='Column', y='Normalized', data=df_std)
#_ = ax.set_xticklabels(label_name, rotation=90)
_ = ax.set_xticklabels(dataset.columns, rotation=90)

# %%
dataset_std
# Out:
#       spatter:N    FBcurr    FBvolt    Shrt:T     Arc:T    Shrt:N    Plus:N  \
# 0     -0.245456 -0.359241  0.180913 -0.713875  0.158828  1.482689  1.680821
# 1     -0.806037 -0.923466 -0.754852 -0.723037 -0.627706  1.482689  1.030459
# 2     -0.806037 -1.211279 -0.900564 -0.666757 -0.827274 -0.989828  1.030459
# 3     -1.055184 -1.133366 -1.169951 -0.729581 -1.199997 -0.165656  0.380098
# 4     -0.961753 -1.051997 -1.023897 -0.745287 -1.018037 -0.989828 -0.270264
# ...         ...       ...       ...       ...       ...       ...       ...
# 3607   0.190550  0.619255  0.755559  0.919553  0.540355 -0.165656 -0.270264
# 3608   0.190550  0.155575  0.690476 -0.187723  0.593182 -0.989828 -0.270264
# 3609   0.097120  0.243509  0.254537  1.542558  0.194045 -0.165656 -0.270264
# 3610   0.906847  0.985328  1.399901  1.203570  1.338627 -0.165656 -0.270264
# 3611   0.470841  1.324623  1.199185 -0.245311  0.936556 -0.989828 -0.270264
#
#       Arc-Peak:V  Arc-Peak:I  ShrtOpn:I  preShrt-Arc:I  PlusBase_brnbk:N  \
# 0       2.001038    3.343416  -0.797526      -0.067228          6.310623
# 1      -0.162240    0.208323  -0.677852       0.092795          1.943544
# 2      -0.166564    0.229304  -0.666589      -0.899350          6.310623
# 3      -0.173770    0.182847  -0.932686      -0.595305         -0.239996
# 4      -0.894383   -0.848197  -0.835540      -0.899350          4.127083
# ...          ...         ...        ...            ...               ...
# 3607   -0.894383   -0.848197   1.804320       1.308973         -0.239996
# 3608   -0.894383   -0.848197  -0.034430      -0.899350         -0.239996
# 3609    0.424338    0.475076   0.822996       0.007450         -0.239996
# 3610    0.545401    0.526028   1.076423       0.428845         -0.239996
# 3611    0.503606    0.461588   2.439294       1.372982         -0.239996
#
#       1cyc-corrI  1cyc-corrT
# 0      -0.030536    1.078679
# 1       0.084577    1.078679
# 2       0.216134    1.331284
# 3      -0.277205    0.068257
# 4      -0.277205   -0.184349
# ...          ...         ...
# 3607   -1.790114   -0.184349
# 3608   -1.790114   -0.184349
# 3609   -1.543444   -0.184349
# 3610   -1.033660   -0.184349
# 3611   -2.299898   -0.184349
#
# [3612 rows x 14 columns]

# %%
#データを入力(X)４つ、出力(Y)２つに分ける
#CurrFB, VoltFBのうちCurrFBだけ除外してみる。
input_data = dataset_std.iloc[:, 2:13].values
output_data = dataset_std.iloc[:, 0:1].values
print( 'input_data=[', input_data.shape[0], ',', input_data.shape[1], ']')
print( 'output_data=[', output_data.shape[0], ',', output_data.shape[1],']')
# Out:
# input_data=[ 3612 , 11 ]
# output_data=[ 3612 , 1 ]

# %%
Xdata=[]
Ydata=[]
#LSTM用にデータ加工
#入力データの時間：10x6ms 60ms間の傾向
look_back=1
number = int( output_data.shape[0] / look_back ) - 1
print('Number=',number)
for i in range(number):
    Xtimedata=[]
    data_head = i * look_back
    for j in range(input_data.shape[1]):
        Xtimedata.append(input_data[data_head:data_head+look_back,j])
    Xtimedata=np.array(Xtimedata)
    Xtimedata=Xtimedata.transpose()
    Xdata.append(Xtimedata)
    Ytimedata=[]
    sum=0
    for j in range(look_back):
        sum += output_data[data_head+j,0]
    Ytimedata.append(sum/look_back)
    Ydata.append(Ytimedata)
# Out:
# Number= 3611

# %%
Xdata=np.array(Xdata)
Ydata=np.array(Ydata)

print(Xdata.shape)
#print(Xdata)
print(Ydata.shape)
#print(Ydata)
# Out:
# (3611, 1, 11)
# (3611, 1)

# %%
#ライブラリインポート
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.optimizers import Adam

# %%
input_data.shape[0]
# Out:
# 3612

# %%
#学習用の情報指定
Xdim=Xdata.shape[2]
Ydim=Ydata.shape[1]
validation_split_rate=0.2
print('Xdim=',Xdim,', Ydim=',Ydim,', validation_split_rate=',validation_split_rate)
# Out:
# Xdim= 11 , Ydim= 1 , validation_split_rate= 0.2

# %%
#モデル構築
#LSTMレイヤを多層化して複雑な表現ができるようにする。
#LSTM(34,...の34はユニット数でより複雑で長期的な傾向を理解するためにはユニット数をある程度の大きさにする。

model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(look_back,Xdim)))
model.add(LSTM(50, return_sequences=True))
model.add(LSTM(50))
model.add(Dense(Ydim))
model.compile(loss="mean_squared_error", optimizer=Adam(learning_rate=0.001))
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_9 (LSTM)               (None, 1, 50)             12400
#
#  lstm_10 (LSTM)              (None, 1, 50)             20200
#
#  lstm_11 (LSTM)              (None, 50)                20200
#
#  dense_3 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 52,851
# Trainable params: 52,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
#学習開始
history=model.fit(Xdata,Ydata,batch_size=16,epochs=250,validation_split=validation_split_rate)
# Out:
# Epoch 1/250
# 181/181 [==============================] - 10s 15ms/step - loss: 0.3504 - val_loss: 0.0906
# Epoch 2/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0774 - val_loss: 0.0811
# Epoch 3/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0717 - val_loss: 0.0877
# Epoch 4/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0681 - val_loss: 0.0803
# Epoch 5/250
# 181/181 [==============================] - 2s 8ms/step - loss: 0.0681 - val_loss: 0.0797
# Epoch 6/250
# 181/181 [==============================] - 2s 10ms/step - loss: 0.0679 - val_loss: 0.0821
# Epoch 7/250
# 181/181 [==============================] - 2s 10ms/step - loss: 0.0680 - val_loss: 0.0782
# Epoch 8/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0653 - val_loss: 0.0794
# Epoch 9/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0628 - val_loss: 0.0795
# Epoch 10/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0639 - val_loss: 0.0847
# Epoch 11/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0631 - val_loss: 0.0841
# Epoch 12/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0629 - val_loss: 0.0857
# Epoch 13/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0614 - val_loss: 0.0875
# Epoch 14/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0619 - val_loss: 0.0790
# Epoch 15/250
# 181/181 [==============================] - 2s 9ms/step - loss: 0.0640 - val_loss: 0.0785
# Epoch 16/250
# 181/181 [==============================] - 2s 9ms/step - loss: 0.0597 - val_loss: 0.0811
# Epoch 17/250
# 181/181 [==============================] - 2s 10ms/step - loss: 0.0643 - val_loss: 0.0794
# Epoch 18/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0606 - val_loss: 0.0863
# Epoch 19/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0584 - val_loss: 0.0923
# Epoch 20/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0581 - val_loss: 0.0959
# Epoch 21/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0569 - val_loss: 0.0789
# Epoch 22/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0606 - val_loss: 0.0796
# Epoch 23/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0577 - val_loss: 0.0880
# Epoch 24/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0560 - val_loss: 0.0849
# Epoch 25/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0549 - val_loss: 0.0799
# Epoch 26/250
# 181/181 [==============================] - 2s 10ms/step - loss: 0.0566 - val_loss: 0.0812
# Epoch 27/250
# 181/181 [==============================] - 2s 10ms/step - loss: 0.0535 - val_loss: 0.0805
# Epoch 28/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0532 - val_loss: 0.0812
# Epoch 29/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0528 - val_loss: 0.0937
# Epoch 30/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0518 - val_loss: 0.0886
# Epoch 31/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0528 - val_loss: 0.0876
# Epoch 32/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0502 - val_loss: 0.0879
# Epoch 33/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0485 - val_loss: 0.0804
# Epoch 34/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0522 - val_loss: 0.0842
# Epoch 35/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0516 - val_loss: 0.0989
# Epoch 36/250
# 181/181 [==============================] - 2s 10ms/step - loss: 0.0476 - val_loss: 0.0807
# Epoch 37/250
# 181/181 [==============================] - 2s 10ms/step - loss: 0.0476 - val_loss: 0.0822
# Epoch 38/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0463 - val_loss: 0.0787
# Epoch 39/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0478 - val_loss: 0.0784
# Epoch 40/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0465 - val_loss: 0.1051
# Epoch 41/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0457 - val_loss: 0.0784
# Epoch 42/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0449 - val_loss: 0.0865
# Epoch 43/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0461 - val_loss: 0.0810
# Epoch 44/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0452 - val_loss: 0.0793
# Epoch 45/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0469 - val_loss: 0.0816
# Epoch 46/250
# 181/181 [==============================] - 2s 10ms/step - loss: 0.0460 - val_loss: 0.0778
# Epoch 47/250
# 181/181 [==============================] - 2s 10ms/step - loss: 0.0448 - val_loss: 0.0790
# Epoch 48/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0450 - val_loss: 0.0779
# Epoch 49/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0461 - val_loss: 0.1014
# Epoch 50/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0450 - val_loss: 0.0803
# Epoch 51/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0433 - val_loss: 0.0931
# Epoch 52/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0427 - val_loss: 0.0931
# Epoch 53/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0459 - val_loss: 0.0845
# Epoch 54/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0489 - val_loss: 0.0821
# Epoch 55/250
# 181/181 [==============================] - 2s 8ms/step - loss: 0.0440 - val_loss: 0.0820
# Epoch 56/250
# 181/181 [==============================] - 2s 10ms/step - loss: 0.0451 - val_loss: 0.0931
# Epoch 57/250
# 181/181 [==============================] - 2s 10ms/step - loss: 0.0419 - val_loss: 0.0830
# Epoch 58/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0445 - val_loss: 0.0771
# Epoch 59/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0406 - val_loss: 0.0908
# Epoch 60/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0428 - val_loss: 0.0791
# Epoch 61/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0414 - val_loss: 0.0797
# Epoch 62/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0427 - val_loss: 0.0777
# Epoch 63/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0441 - val_loss: 0.0791
# Epoch 64/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0427 - val_loss: 0.0812
# Epoch 65/250
# 181/181 [==============================] - 2s 9ms/step - loss: 0.0417 - val_loss: 0.0789
# Epoch 66/250
# 181/181 [==============================] - 2s 10ms/step - loss: 0.0415 - val_loss: 0.0770
# Epoch 67/250
# 181/181 [==============================] - 2s 10ms/step - loss: 0.0435 - val_loss: 0.1134
# Epoch 68/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0423 - val_loss: 0.0912
# Epoch 69/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0406 - val_loss: 0.0854
# Epoch 70/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0394 - val_loss: 0.0831
# Epoch 71/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0430 - val_loss: 0.0901
# Epoch 72/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0439 - val_loss: 0.0808
# Epoch 73/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0401 - val_loss: 0.0803
# Epoch 74/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0402 - val_loss: 0.0789
# Epoch 75/250
# 181/181 [==============================] - 2s 10ms/step - loss: 0.0391 - val_loss: 0.0820
# Epoch 76/250
# 181/181 [==============================] - 2s 10ms/step - loss: 0.0417 - val_loss: 0.1043
# Epoch 77/250
# 181/181 [==============================] - 2s 9ms/step - loss: 0.0408 - val_loss: 0.0992
# Epoch 78/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0426 - val_loss: 0.0851
# Epoch 79/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0382 - val_loss: 0.0801
# Epoch 80/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0389 - val_loss: 0.1133
# Epoch 81/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0402 - val_loss: 0.0818
# Epoch 82/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0387 - val_loss: 0.0845
# Epoch 83/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0398 - val_loss: 0.0802
# Epoch 84/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0394 - val_loss: 0.0865
# Epoch 85/250
# 181/181 [==============================] - 2s 10ms/step - loss: 0.0394 - val_loss: 0.0858
# Epoch 86/250
# 181/181 [==============================] - 2s 10ms/step - loss: 0.0400 - val_loss: 0.0868
# Epoch 87/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0394 - val_loss: 0.1119
# Epoch 88/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0384 - val_loss: 0.0838
# Epoch 89/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0400 - val_loss: 0.0863
# Epoch 90/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0374 - val_loss: 0.0813
# Epoch 91/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0428 - val_loss: 0.0824
# Epoch 92/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0387 - val_loss: 0.0942
# Epoch 93/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0399 - val_loss: 0.0857
# Epoch 94/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0385 - val_loss: 0.0883
# Epoch 95/250
# 181/181 [==============================] - 2s 10ms/step - loss: 0.0363 - val_loss: 0.0815
# Epoch 96/250
# 181/181 [==============================] - 2s 10ms/step - loss: 0.0385 - val_loss: 0.0842
# Epoch 97/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0379 - val_loss: 0.0893
# Epoch 98/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0388 - val_loss: 0.0879
# Epoch 99/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0382 - val_loss: 0.0847
# Epoch 100/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0359 - val_loss: 0.0832
# Epoch 101/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0359 - val_loss: 0.0881
# Epoch 102/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0375 - val_loss: 0.0807
# Epoch 103/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0365 - val_loss: 0.0802
# Epoch 104/250
# 181/181 [==============================] - 2s 8ms/step - loss: 0.0362 - val_loss: 0.0879
# Epoch 105/250
# 181/181 [==============================] - 2s 10ms/step - loss: 0.0356 - val_loss: 0.0856
# Epoch 106/250
# 181/181 [==============================] - 2s 10ms/step - loss: 0.0375 - val_loss: 0.0835
# Epoch 107/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0360 - val_loss: 0.0812
# Epoch 108/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0351 - val_loss: 0.0817
# Epoch 109/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0353 - val_loss: 0.0845
# Epoch 110/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0365 - val_loss: 0.0858
# Epoch 111/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0352 - val_loss: 0.0928
# Epoch 112/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0362 - val_loss: 0.0800
# Epoch 113/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0355 - val_loss: 0.0805
# Epoch 114/250
# 181/181 [==============================] - 2s 9ms/step - loss: 0.0348 - val_loss: 0.0852
# Epoch 115/250
# 181/181 [==============================] - 2s 9ms/step - loss: 0.0350 - val_loss: 0.0881
# Epoch 116/250
# 181/181 [==============================] - 2s 9ms/step - loss: 0.0367 - val_loss: 0.0855
# Epoch 117/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0349 - val_loss: 0.0908
# Epoch 118/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0343 - val_loss: 0.0849
# Epoch 119/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0352 - val_loss: 0.0928
# Epoch 120/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0363 - val_loss: 0.0837
# Epoch 121/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0348 - val_loss: 0.0869
# Epoch 122/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0343 - val_loss: 0.0852
# Epoch 123/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0338 - val_loss: 0.0845
# Epoch 124/250
# 181/181 [==============================] - 2s 9ms/step - loss: 0.0336 - val_loss: 0.0850
# Epoch 125/250
# 181/181 [==============================] - 2s 10ms/step - loss: 0.0362 - val_loss: 0.0826
# Epoch 126/250
# 181/181 [==============================] - 2s 9ms/step - loss: 0.0352 - val_loss: 0.0965
# Epoch 127/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0363 - val_loss: 0.0943
# Epoch 128/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0340 - val_loss: 0.0862
# Epoch 129/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0333 - val_loss: 0.1015
# Epoch 130/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0348 - val_loss: 0.0850
# Epoch 131/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0370 - val_loss: 0.0821
# Epoch 132/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0329 - val_loss: 0.0841
# Epoch 133/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0328 - val_loss: 0.0928
# Epoch 134/250
# 181/181 [==============================] - 2s 9ms/step - loss: 0.0356 - val_loss: 0.0844
# Epoch 135/250
# 181/181 [==============================] - 2s 10ms/step - loss: 0.0362 - val_loss: 0.0926
# Epoch 136/250
# 181/181 [==============================] - 2s 10ms/step - loss: 0.0357 - val_loss: 0.0838
# Epoch 137/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0330 - val_loss: 0.0908
# Epoch 138/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0326 - val_loss: 0.0862
# Epoch 139/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0331 - val_loss: 0.0841
# Epoch 140/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0338 - val_loss: 0.0859
# Epoch 141/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0326 - val_loss: 0.0893
# Epoch 142/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0333 - val_loss: 0.0888
# Epoch 143/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0329 - val_loss: 0.0847
# Epoch 144/250
# 181/181 [==============================] - 2s 9ms/step - loss: 0.0342 - val_loss: 0.0849
# Epoch 145/250
# 181/181 [==============================] - 2s 9ms/step - loss: 0.0322 - val_loss: 0.0868
# Epoch 146/250
# 181/181 [==============================] - 2s 9ms/step - loss: 0.0316 - val_loss: 0.0922
# Epoch 147/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0315 - val_loss: 0.0864
# Epoch 148/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0326 - val_loss: 0.0888
# Epoch 149/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0325 - val_loss: 0.0861
# Epoch 150/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0320 - val_loss: 0.0878
# Epoch 151/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0329 - val_loss: 0.0880
# Epoch 152/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0314 - val_loss: 0.0843
# Epoch 153/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0342 - val_loss: 0.0907
# Epoch 154/250
# 181/181 [==============================] - 2s 10ms/step - loss: 0.0317 - val_loss: 0.0920
# Epoch 155/250
# 181/181 [==============================] - 2s 10ms/step - loss: 0.0311 - val_loss: 0.0936
# Epoch 156/250
# 181/181 [==============================] - 2s 9ms/step - loss: 0.0330 - val_loss: 0.0848
# Epoch 157/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0303 - val_loss: 0.0862
# Epoch 158/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0319 - val_loss: 0.0894
# Epoch 159/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0308 - val_loss: 0.0853
# Epoch 160/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0304 - val_loss: 0.0870
# Epoch 161/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0323 - val_loss: 0.0865
# Epoch 162/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0313 - val_loss: 0.0834
# Epoch 163/250
# 181/181 [==============================] - 2s 9ms/step - loss: 0.0327 - val_loss: 0.0838
# Epoch 164/250
# 181/181 [==============================] - 2s 10ms/step - loss: 0.0308 - val_loss: 0.0846
# Epoch 165/250
# 181/181 [==============================] - 2s 10ms/step - loss: 0.0306 - val_loss: 0.0956
# Epoch 166/250
# 181/181 [==============================] - 2s 9ms/step - loss: 0.0314 - val_loss: 0.0878
# Epoch 167/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0292 - val_loss: 0.0863
# Epoch 168/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0311 - val_loss: 0.0859
# Epoch 169/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0294 - val_loss: 0.0837
# Epoch 170/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0290 - val_loss: 0.0964
# Epoch 171/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0304 - val_loss: 0.0940
# Epoch 172/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0303 - val_loss: 0.0865
# Epoch 173/250
# 181/181 [==============================] - 2s 8ms/step - loss: 0.0293 - val_loss: 0.0913
# Epoch 174/250
# 181/181 [==============================] - 2s 10ms/step - loss: 0.0289 - val_loss: 0.0995
# Epoch 175/250
# 181/181 [==============================] - 2s 10ms/step - loss: 0.0288 - val_loss: 0.0900
# Epoch 176/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0304 - val_loss: 0.0951
# Epoch 177/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0294 - val_loss: 0.0874
# Epoch 178/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0291 - val_loss: 0.0946
# Epoch 179/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0282 - val_loss: 0.0905
# Epoch 180/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0278 - val_loss: 0.0903
# Epoch 181/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0289 - val_loss: 0.0926
# Epoch 182/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0278 - val_loss: 0.0924
# Epoch 183/250
# 181/181 [==============================] - 2s 9ms/step - loss: 0.0282 - val_loss: 0.0952
# Epoch 184/250
# 181/181 [==============================] - 2s 10ms/step - loss: 0.0337 - val_loss: 0.0877
# Epoch 185/250
# 181/181 [==============================] - 2s 10ms/step - loss: 0.0289 - val_loss: 0.0879
# Epoch 186/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0272 - val_loss: 0.1033
# Epoch 187/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0306 - val_loss: 0.0908
# Epoch 188/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0265 - val_loss: 0.0890
# Epoch 189/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0273 - val_loss: 0.0929
# Epoch 190/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0281 - val_loss: 0.0986
# Epoch 191/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0266 - val_loss: 0.0873
# Epoch 192/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0264 - val_loss: 0.0868
# Epoch 193/250
# 181/181 [==============================] - 2s 9ms/step - loss: 0.0278 - val_loss: 0.1157
# Epoch 194/250
# 181/181 [==============================] - 2s 10ms/step - loss: 0.0307 - val_loss: 0.0953
# Epoch 195/250
# 181/181 [==============================] - 2s 10ms/step - loss: 0.0261 - val_loss: 0.0875
# Epoch 196/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0274 - val_loss: 0.0922
# Epoch 197/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0275 - val_loss: 0.0886
# Epoch 198/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0259 - val_loss: 0.0989
# Epoch 199/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0270 - val_loss: 0.0964
# Epoch 200/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0264 - val_loss: 0.0924
# Epoch 201/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0268 - val_loss: 0.0883
# Epoch 202/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0265 - val_loss: 0.0931
# Epoch 203/250
# 181/181 [==============================] - 2s 9ms/step - loss: 0.0267 - val_loss: 0.0915
# Epoch 204/250
# 181/181 [==============================] - 2s 10ms/step - loss: 0.0256 - val_loss: 0.0952
# Epoch 205/250
# 181/181 [==============================] - 2s 10ms/step - loss: 0.0271 - val_loss: 0.0978
# Epoch 206/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0263 - val_loss: 0.0918
# Epoch 207/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0253 - val_loss: 0.0930
# Epoch 208/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0251 - val_loss: 0.0941
# Epoch 209/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0246 - val_loss: 0.0949
# Epoch 210/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0248 - val_loss: 0.0962
# Epoch 211/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0243 - val_loss: 0.0982
# Epoch 212/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0246 - val_loss: 0.0924
# Epoch 213/250
# 181/181 [==============================] - 2s 9ms/step - loss: 0.0260 - val_loss: 0.1011
# Epoch 214/250
# 181/181 [==============================] - 2s 10ms/step - loss: 0.0254 - val_loss: 0.0932
# Epoch 215/250
# 181/181 [==============================] - 2s 10ms/step - loss: 0.0239 - val_loss: 0.0933
# Epoch 216/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0254 - val_loss: 0.1007
# Epoch 217/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0246 - val_loss: 0.1106
# Epoch 218/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0242 - val_loss: 0.1053
# Epoch 219/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0235 - val_loss: 0.1058
# Epoch 220/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0253 - val_loss: 0.0991
# Epoch 221/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0260 - val_loss: 0.0950
# Epoch 222/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0233 - val_loss: 0.1018
# Epoch 223/250
# 181/181 [==============================] - 2s 9ms/step - loss: 0.0245 - val_loss: 0.1062
# Epoch 224/250
# 181/181 [==============================] - 2s 10ms/step - loss: 0.0229 - val_loss: 0.0941
# Epoch 225/250
# 181/181 [==============================] - 2s 10ms/step - loss: 0.0225 - val_loss: 0.1037
# Epoch 226/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0232 - val_loss: 0.0958
# Epoch 227/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0232 - val_loss: 0.1054
# Epoch 228/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0233 - val_loss: 0.0987
# Epoch 229/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0222 - val_loss: 0.1005
# Epoch 230/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0219 - val_loss: 0.0997
# Epoch 231/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0222 - val_loss: 0.1007
# Epoch 232/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0230 - val_loss: 0.0996
# Epoch 233/250
# 181/181 [==============================] - 2s 9ms/step - loss: 0.0239 - val_loss: 0.1025
# Epoch 234/250
# 181/181 [==============================] - 2s 10ms/step - loss: 0.0222 - val_loss: 0.1037
# Epoch 235/250
# 181/181 [==============================] - 2s 10ms/step - loss: 0.0224 - val_loss: 0.0968
# Epoch 236/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0216 - val_loss: 0.1066
# Epoch 237/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0219 - val_loss: 0.1032
# Epoch 238/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0217 - val_loss: 0.1027
# Epoch 239/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0213 - val_loss: 0.1009
# Epoch 240/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0211 - val_loss: 0.1084
# Epoch 241/250
# 181/181 [==============================] - 2s 8ms/step - loss: 0.0221 - val_loss: 0.1019
# Epoch 242/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0216 - val_loss: 0.1047
# Epoch 243/250
# 181/181 [==============================] - 2s 11ms/step - loss: 0.0211 - val_loss: 0.1035
# Epoch 244/250
# 181/181 [==============================] - 2s 10ms/step - loss: 0.0203 - val_loss: 0.1024
# Epoch 245/250
# 181/181 [==============================] - 2s 8ms/step - loss: 0.0204 - val_loss: 0.1027
# Epoch 246/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0205 - val_loss: 0.1045
# Epoch 247/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0220 - val_loss: 0.1048
# Epoch 248/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0205 - val_loss: 0.1080
# Epoch 249/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0205 - val_loss: 0.1067
# Epoch 250/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0208 - val_loss: 0.1121

# %%
#学習履歴のグラフ化
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
#学習データから学習時にテストデータとして用いた部分を取り出す
Xdata_validation=Xdata[-int(len(Xdata)*(validation_split_rate)):]
Ydata_validation=Ydata[-int(len(Ydata)*(validation_split_rate)):]

# %%
#テスト
Predictdata = model.predict(Xdata_validation)
#テスト結果のグラフ化
plt.plot(range(0, len(Predictdata)),Predictdata[:,0], color="b", label="predict")
plt.plot(range(0, len(Ydata_validation)),Ydata_validation[:,0], color="r", label="row_data")
plt.legend()
plt.show()
# Out:
# 23/23 [==============================] - 1s 2ms/step

# %%
import pandas as pd
predict_df = pd.DataFrame(Predictdata, columns=["predict"])
validation_df = pd.DataFrame(Ydata_validation, columns=["row_data"])
predict_df.to_csv("/content/drive/MyDrive/Colab Notebooks/RENEW_predict_data0623-1.csv", index=False)
validation_df.to_csv("/content/drive/MyDrive/Colab Notebooks/RENEW_validation_data0623-1.csv", index=False)
