# %% [markdown]
# <a href="https://colab.research.google.com/github/SeiichiroFukushima/keras/blob/master/LSTM_try04-8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 複数の実験データから大規模なデータセットを準備する
#
# ＜時系列データフレームの準備＞
# *   指定されたパス内のフォルダ構造も解析してパス付のCSVファイルのリストを作成する。
# *   CSVファイルリストでループを回す。
# *   上記ループ内でCSVファイルをロードする。
# *   ロードしたデータをデータフレーム化して、タイムスタンプをカラムに追加する。
# *   ロードしたCSVファイルのラベルリストを準備する。
# *   不要なインデックスをラベルリストを準備する。
# *   データフレームから不要なカラムを除外する。
# *   不要なデータ行（例えば、データNo.、カメラ時間、カメラ時間がゼロでスパッタ発生量がゼロの行、等）を除外する。
# *   さらに指定された溶接開始時間と溶接終了時間を除いたメイン溶接のデータ行だけにする。
# *   リスト項目
# *   リスト項目
#
#
# ＜時系列データフレームのダウンサンプリングと正規化＞
# *   リスト項目
# *   リスト項目
# *   リスト項目

# %%
import os
import random
import pandas as pd
from datetime import timedelta
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Googleドライブのマウント

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## フォルダパス内のCSVファイルのリストを作成する

# %%
folder_path ='/content/drive/MyDrive/Colab Notebooks/dataset/welding_data'

# フォルダパス内のCSVファイルのリストを作成する
csv_files = []
for root, dirs, files in os.walk(folder_path):
    for file in files:
        if file.endswith(".csv"):
            csv_files.append(os.path.join(root, file))

random.shuffle(csv_files)

print(csv_files)
# Out:
# ['/content/drive/MyDrive/Colab Notebooks/dataset/welding_data/W12_CO2Shrt/RENEW_No_94_WeldValue_20230530210416.csv', '/content/drive/MyDrive/Colab Notebooks/dataset/welding_data/W12_MAGShrt/RENEW_No_149_WeldValue_20230530144046.csv', '/content/drive/MyDrive/Colab Notebooks/dataset/welding_data/W12_MAGShrt/RENEW_No_252_WeldValue_20230530153852.csv', '/content/drive/MyDrive/Colab Notebooks/dataset/welding_data/W12_MAGPlus/RENEW_No_56_WeldValue_20230519142414.csv', '/content/drive/MyDrive/Colab Notebooks/dataset/welding_data/W12_MAGPlus/RENEW_No_234_WeldValue_20230519154714.csv', '/content/drive/MyDrive/Colab Notebooks/dataset/welding_data/W12_MAGShrt/RENEW_No_249_WeldValue_20230530151411.csv', '/content/drive/MyDrive/Colab Notebooks/dataset/welding_data/W12_CO2Shrt/RENEW_No_250_WeldValue_20230531073005.csv', '/content/drive/MyDrive/Colab Notebooks/dataset/welding_data/W12_MAGShrt/RENEW_No_94_WeldValue_20230530142553.csv', '/content/drive/MyDrive/Colab Notebooks/dataset/welding_data/W12_MAGPlus/RENEW_No_6_WeldValue_20230519135939.csv', '/content/drive/MyDrive/Colab Notebooks/dataset/welding_data/W12_CO2Shrt/RENEW_No_248_WeldValue_20230530214711.csv', '/content/drive/MyDrive/Colab Notebooks/dataset/welding_data/W12_MAGPlus/RENEW_No_241_WeldValue_20230519155716.csv', '/content/drive/MyDrive/Colab Notebooks/dataset/welding_data/W12_CO2Shrt/RENEW_No_204_WeldValue_20230530212658.csv', '/content/drive/MyDrive/Colab Notebooks/dataset/welding_data/W12_MAGShrt/RENEW_No_28_WeldValue_20230530134404.csv', '/content/drive/MyDrive/Colab Notebooks/dataset/welding_data/W12_MAGPlus/RENEW_No_204_WeldValue_20230519150605.csv', '/content/drive/MyDrive/Colab Notebooks/dataset/welding_data/W12_CO2Shrt/RENEW_No_116_WeldValue_20230530211048.csv', '/content/drive/MyDrive/Colab Notebooks/dataset/welding_data/W12_CO2Shrt/RENEW_No_254_WeldValue_20230531075220.csv', '/content/drive/MyDrive/Colab Notebooks/dataset/welding_data/W12_CO2Shrt/RENEW_No_149_WeldValue_20230530212109.csv', '/content/drive/MyDrive/Colab Notebooks/dataset/welding_data/W12_CO2Shrt/RENEW_No_61_WeldValue_20230530201755.csv', '/content/drive/MyDrive/Colab Notebooks/dataset/welding_data/W12_CO2Shrt/RENEW_No_6_WeldValue_20230530202732.csv', '/content/drive/MyDrive/Colab Notebooks/dataset/welding_data/W12_MAGPlus/RENEW_No_226_WeldValue_20230519153232.csv', '/content/drive/MyDrive/Colab Notebooks/dataset/welding_data/W12_MAGPlus/RENEW_No_149_WeldValue_20230519150203.csv', '/content/drive/MyDrive/Colab Notebooks/dataset/welding_data/W12_CO2Shrt/RENEW_No_249_WeldValue_20230531072446.csv', '/content/drive/MyDrive/Colab Notebooks/dataset/welding_data/W12_MAGShrt/RENEW_No_116_WeldValue_20230530143033.csv', '/content/drive/MyDrive/Colab Notebooks/dataset/welding_data/W12_MAGShrt/RENEW_No_246_WeldValue_20230530145755.csv', '/content/drive/MyDrive/Colab Notebooks/dataset/welding_data/W12_CO2Shrt/RENEW_No_255_WeldValue_20230531075723.csv', '/content/drive/MyDrive/Colab Notebooks/dataset/welding_data/W12_MAGShrt/RENEW_No_66_WeldValue_20230530142121.csv', '/content/drive/MyDrive/Colab Notebooks/dataset/welding_data/W12_MAGShrt/RENEW_No_227_WeldValue_20230530145236.csv', '/content/drive/MyDrive/Colab Notebooks/dataset/welding_data/W12_MAGPlus/RENEW_No_249_WeldValue_20230519161615.csv', '/content/drive/MyDrive/Colab Notebooks/dataset/welding_data/W12_MAGShrt/RENEW_No_247_WeldValue_20230530150321.csv', '/content/drive/MyDrive/Colab Notebooks/dataset/welding_data/W12_CO2Shrt/RENEW_No_252_WeldValue_20230531074027.csv', '/content/drive/MyDrive/Colab Notebooks/dataset/welding_data/W12_CO2Shrt/RENEW_No_66_WeldValue_20230530205846.csv', '/content/drive/MyDrive/Colab Notebooks/dataset/welding_data/W12_MAGPlus/RENEW_No_61_WeldValue_20230519135607.csv', '/content/drive/MyDrive/Colab Notebooks/dataset/welding_data/W12_MAGShrt/RENEW_No_61_WeldValue_20230530140328.csv', '/content/drive/MyDrive/Colab Notebooks/dataset/welding_data/W12_MAGShrt/RENEW_No_250_WeldValue_20230530152324.csv', '/content/drive/MyDrive/Colab Note ...

# %% [markdown]
# # 溶接電源特徴量及びスパッタ発生量データのフォーマット
# >   index データ名称
# *   	0   No.
# *     1	  ｶﾒﾗ時間
# *     2	  ｽﾊﾟｯﾀ量
# *     3	  FB電流
# *   	4	  FB電圧
# *   	5	  ｱｰｸ切れ発生時間
# *   	6	  短絡時間
# *   	7	  ｱｰｸ時間
# *   	8   短絡回数
# *   	9	  ﾊﾟﾙｽ回数
# *   	10	ﾈｯｷﾝｸﾞ失敗回数
# *   	11	ﾈｯｷﾝｸﾞ時間
# *   	12	ｱｰｸ期間ﾋﾟｰｸ電圧
# *   	13	ｱｰｸ期間ﾋﾟｰｸ電流
# *   	14	短絡開放電流
# *   	15	短絡移行前ｱｰｸ電流
# *   	16	微小短絡回数
# *   	17	微小短絡発生前ｱｰｸ電流
# *   	18	異常短絡開放発生回数
# *   	19	ﾋﾟｰｸ短絡回数
# *   	20	ﾊﾟﾙｽﾍﾞｰｽ時燃え上がり発生回数
# *   	21	電流補償継続時間
# *   	22	1周期毎の電流補正量
# *   	23	1周期毎の電圧補正量
# *   	24	1周期毎の時間補正量
# *   	25	1周期毎の送給速度補正量
# *   	26	予備

# %%
# 溶接電源特徴量及びスパッタ発生量データのフォーマットを参考にCSVファイルのラベルリストを準備
label_list = ['No.','CameraTime','spatter:N','FBcurr','FBvolt','ArcCut:T','Shrt:T','Arc:T','Shrt:N','Plus:N','NeckMis:N','Neck:T','Arc-Peak:V','Arc-Peak:I','ShrtOpn:I','preShrt-Arc:I','microShrt:N','microShort-ArcI','Abnrml_ShrtOpn:N','Peak-Shrt:N','PlusBase_brnbk:N','currI_kep:T','1cyc-corrI','1cyc_corrV','1cyc-corrT','1cyc-corrWFS','reserve']

# ****** 溶接電源特徴量及びスパッタ発生量データの不要なデータ列の除外 ******
#     非特徴量データを除外
#     Name:'No.','CameraTime'
#
#     'FBcurr','FBvolt'のうち'FBcurr'だけ除外。
#     Name:'FBcurr'
#
#     ＣＯ２短絡、ＭＡＧ短絡、ＭＡＧパルスの時系列データから共通してゼロ値のデータのものを除外。
#     Name:'ArcCut:T', 'Abnrml_ShrtOpn:N', '1cyc_corrV','1cyc-corrWFS','reserve'
# まとめると、

# 不要な時系列データのラベルリスト
# ＣＯ２短絡、ＭＡＧ短絡、ＭＡＧパルスの時系列データから共通してゼロ値のデータのものを除外。（ＡＮＤ条件）
#unwanted_columns = ['No.','CameraTime','FBcurr','ArcCut:T','Abnrml_ShrtOpn:N','1cyc_corrV','1cyc-corrWFS','reserve']
# ＣＯ２短絡、ＭＡＧ短絡、ＭＡＧパルスのいづれか時系列データでゼロ値のデータのものを除外。（ＯＲ条件）
unwanted_columns = ['No.','CameraTime','ArcCut:T','NeckMis:N','Neck:T','microShrt:N','microShort-ArcI','Abnrml_ShrtOpn:N','Peak-Shrt:N', 'currI_kep:T', '1cyc_corrV','1cyc-corrWFS','reserve']

# %%
# CSVファイルをロードしてデータフレーム化する
data = pd.read_csv(csv_files[1]).values

# ndarrayをデータフレームに変換
df = pd.DataFrame(data=data, columns=label_list)

# タイムスタンプの範囲を生成
time_index = pd.date_range(start='2023-05-28 00:00:00', periods=len(df), freq='500us')
# タイムスタンプをデータフレームのインデックスとして設定
df = df.set_index(time_index)

# %%
df
# Out:
#                              No.  CameraTime  spatter:N  FBcurr  FBvolt  \
# 2023-05-28 00:00:00.000000     1      327500          0     323       0
# 2023-05-28 00:00:00.000500     2      328000          1      54       6
# 2023-05-28 00:00:00.001000     3      328500          0     134      24
# 2023-05-28 00:00:00.001500     4      329000          0     294      43
# 2023-05-28 00:00:00.002000     5      329500          0     322      45
# ...                          ...         ...        ...     ...     ...
# 2023-05-28 00:00:04.997000  9995           0          0     324     376
# 2023-05-28 00:00:04.997500  9996           0          0     316     367
# 2023-05-28 00:00:04.998000  9997           0          0     315     376
# 2023-05-28 00:00:04.998500  9998           0          0      80      15
# 2023-05-28 00:00:04.999000  9999           0          0     198      43
#
#                             ArcCut:T  Shrt:T  Arc:T  Shrt:N  Plus:N  ...  \
# 2023-05-28 00:00:00.000000         0      25      0       0       0  ...
# 2023-05-28 00:00:00.000500         0      25      0       1       0  ...
# 2023-05-28 00:00:00.001000         0      25      0       0       0  ...
# 2023-05-28 00:00:00.001500         0      25      0       0       0  ...
# 2023-05-28 00:00:00.002000         0      25      0       0       0  ...
# ...                              ...     ...    ...     ...     ...  ...
# 2023-05-28 00:00:04.997000         0       0     25       0       0  ...
# 2023-05-28 00:00:04.997500         0       0     25       0       0  ...
# 2023-05-28 00:00:04.998000         0      20      5       0       0  ...
# 2023-05-28 00:00:04.998500         0      25      0       1       0  ...
# 2023-05-28 00:00:04.999000         0      25      0       0       0  ...
#
#                             microShort-ArcI  Abnrml_ShrtOpn:N  Peak-Shrt:N  \
# 2023-05-28 00:00:00.000000                0                 0            0
# 2023-05-28 00:00:00.000500                0                 0            0
# 2023-05-28 00:00:00.001000                0                 0            0
# 2023-05-28 00:00:00.001500                0                 0            0
# 2023-05-28 00:00:00.002000                0                 0            0
# ...                                     ...               ...          ...
# 2023-05-28 00:00:04.997000                0                 0            0
# 2023-05-28 00:00:04.997500                0                 0            0
# 2023-05-28 00:00:04.998000                0                 0            0
# 2023-05-28 00:00:04.998500                0                 0            0
# 2023-05-28 00:00:04.999000                0                 0            0
#
#                             PlusBase_brnbk:N  currI_kep:T  1cyc-corrI  \
# 2023-05-28 00:00:00.000000                 0            0           0
# 2023-05-28 00:00:00.000500                 0            0           0
# 2023-05-28 00:00:00.001000                 0            0           0
# 2023-05-28 00:00:00.001500                 0            0           0
# 2023-05-28 00:00:00.002000                 0            0           0
# ...                                      ...          ...         ...
# 2023-05-28 00:00:04.997000                 0            0           0
# 2023-05-28 00:00:04.997500                 0            0           0
# 2023-05-28 00:00:04.998000                 0            0           0
# 2023-05-28 00:00:04.998500                 0            0           0
# 2023-05-28 00:00:04.999000                 0            0           0
#
#                             1cyc_corrV  1cyc-corrT  1cyc-corrWFS  reserve
# 2023-05-28 00:00:00.000000           0           0             0        0
# 2023-05-28 00:00:00.000500           0           0             0        0
# 2023-05-28 00:00:00.001000           0           0             0        0
# 2023-05-28 00:00:00.001500           0           0             0        0
# 2023-05-28 00:00:00.002000           0           0             0        0
# ...                                ...         ...           ...      ...
# 2023-05-28 00:00:04.997000           0           0             0        0
# 2023-05-28 00:00:04.997500           0           0             0        0
# 2023-05-28 00:00:04.998000           0           0             0        0
# 2023-05-28 00:00:04.998500           0           0             0        0
# 2023-05-28 00:00:04.999000           0           0             0        0
#
# [9999 rows x 27 columns]

# %%
# データセットのデータフレームを作成する
dataset = pd.DataFrame()

# CSVファイルリストでループを回す
for csv_file in csv_files:
    # CSVファイルをロードしてデータフレーム化する
    data = pd.read_csv(csv_file).values

    # ndarrayをデータフレームに変換
    df = pd.DataFrame(data=data, columns=label_list)

    # タイムスタンプの範囲を生成
    time_index = pd.date_range(start='2023-05-28 00:00:00', periods=len(df), freq='500us')
    # タイムスタンプをデータフレームのインデックスとして設定
    df = df.set_index(time_index)

    # 不要なデータ行を除外する
    # カメラ時間（'CameraTime'）がゼロでスパッタ発生量（'spatter:N'）がゼロの行を除外する
    df = df[(df["CameraTime"] != 0) & (df["spatter:N"] != 0)]

    # 不要なカラムを除外する
    df = df.drop(columns=unwanted_columns)

    # 指定された溶接開始時間（最初の1秒間）と溶接終了時間（最後の1秒間）を除外する
    start_index = df.index[0] + timedelta(seconds=1)
    end_index = df.index[-1] - timedelta(seconds=1)
    filter_condition = (df.index >= start_index) & (df.index <= end_index)
    filtered_df = df[filter_condition]

    # 50msごとにダウンサンプリング
    df_resampled = filtered_df.resample('50ms').sum()

    # データセットにデータフレームを追加する
    dataset = pd.concat([dataset, df_resampled], ignore_index=True)

# データセットのデータフレームを表示する
print(dataset)
# Out:
#       spatter:N  FBcurr  FBvolt  Shrt:T  Arc:T  Shrt:N  Plus:N  Arc-Peak:V  \
# 0            41   10031   14525     449    783       1       0         485
# 1            24    7028    7936     698    427       0       0         981
# 2            26    8255    9286     685    500       1       0         930
# 3            22    5501    6581     246    365       0       0         913
# 4            46   11822   12762    1058    685       2       0           0
# ...         ...     ...     ...     ...    ...     ...     ...         ...
# 3607          6    1865    2435       0    150       0       0         521
# 3608          1     121     363       0     25       0       0           0
# 3609          4    1767    1718       0    100       0       1         508
# 3610          8    2127    3336       0    200       0       0         513
# 3611          2     908     858       0     50       0       0           0
#
#       Arc-Peak:I  ShrtOpn:I  preShrt-Arc:I  PlusBase_brnbk:N  1cyc-corrI  \
# 0            440          0            366                 0           0
# 1            872        714              0                 0         -92
# 2            890       1453              0                 0           0
# 3            878        759            233                 0           0
# 4              0        784              0                 0         -46
# ...          ...        ...            ...               ...         ...
# 3607         700          0              0                 0           0
# 3608           0          0              0                 0           0
# 3609         676          0              0                 0           0
# 3610         686          0              0                 0           0
# 3611           0          0              0                 0           0
#
#       1cyc-corrT
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ...          ...
# 3607           0
# 3608           0
# 3609          -1
# 3610           0
# 3611           0
#
# [3612 rows x 14 columns]

# %%
dataset
# Out:
#       spatter:N  FBcurr  FBvolt  Shrt:T  Arc:T  Shrt:N  Plus:N  Arc-Peak:V  \
# 0            41   10031   14525     449    783       1       0         485
# 1            24    7028    7936     698    427       0       0         981
# 2            26    8255    9286     685    500       1       0         930
# 3            22    5501    6581     246    365       0       0         913
# 4            46   11822   12762    1058    685       2       0           0
# ...         ...     ...     ...     ...    ...     ...     ...         ...
# 3607          6    1865    2435       0    150       0       0         521
# 3608          1     121     363       0     25       0       0           0
# 3609          4    1767    1718       0    100       0       1         508
# 3610          8    2127    3336       0    200       0       0         513
# 3611          2     908     858       0     50       0       0           0
#
#       Arc-Peak:I  ShrtOpn:I  preShrt-Arc:I  PlusBase_brnbk:N  1cyc-corrI  \
# 0            440          0            366                 0           0
# 1            872        714              0                 0         -92
# 2            890       1453              0                 0           0
# 3            878        759            233                 0           0
# 4              0        784              0                 0         -46
# ...          ...        ...            ...               ...         ...
# 3607         700          0              0                 0           0
# 3608           0          0              0                 0           0
# 3609         676          0              0                 0           0
# 3610         686          0              0                 0           0
# 3611           0          0              0                 0           0
#
#       1cyc-corrT
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ...          ...
# 3607           0
# 3608           0
# 3609          -1
# 3610           0
# 3611           0
#
# [3612 rows x 14 columns]

# %% [markdown]
# # データセットの正規化

# %%
import IPython
import IPython.display
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

train_mean = dataset.mean()
train_std = dataset.std()

df_std = (dataset - train_mean) / train_std

dataset_std = df_std
#df_std = df
df_std = df_std.melt(var_name='Column', value_name='Normalized')
plt.figure(figsize=(12, 6))
ax = sns.violinplot(x='Column', y='Normalized', data=df_std)
#_ = ax.set_xticklabels(label_name, rotation=90)
_ = ax.set_xticklabels(dataset.columns, rotation=90)

# %%
dataset_std
# Out:
#       spatter:N    FBcurr    FBvolt    Shrt:T     Arc:T    Shrt:N    Plus:N  \
# 0      0.034834  0.150738  0.881285 -0.162855  0.704705 -0.165656 -0.270264
# 1     -0.494603 -0.368052 -0.244264  0.163045 -0.340093 -0.989828 -0.270264
# 2     -0.432317 -0.156079 -0.013654  0.146031 -0.125851 -0.165656 -0.270264
# 3     -0.556890 -0.631852 -0.475728 -0.428548 -0.522052 -0.989828 -0.270264
# 4      0.190550  0.460146  0.580125  0.634226  0.417092  0.658517 -0.270264
# ...         ...       ...       ...       ...       ...       ...       ...
# 3607  -1.055184 -1.259997 -1.183958 -0.750522 -1.153039 -0.989828 -0.270264
# 3608  -1.210900 -1.561285 -1.537902 -0.750522 -1.519892 -0.989828 -0.270264
# 3609  -1.117470 -1.276927 -1.306438 -0.750522 -1.299781 -0.989828  0.380098
# 3610  -0.992897 -1.214734 -1.030047 -0.750522 -1.006298 -0.989828 -0.270264
# 3611  -1.179757 -1.425325 -1.453345 -0.750522 -1.446522 -0.989828 -0.270264
#
#       Arc-Peak:V  Arc-Peak:I  ShrtOpn:I  preShrt-Arc:I  PlusBase_brnbk:N  \
# 0      -0.195389   -0.188809  -0.932686       0.076793         -0.239996
# 1       0.519459    0.458591   0.072572      -0.899350         -0.239996
# 2       0.445957    0.485566   1.113029      -0.899350         -0.239996
# 3       0.421456    0.467583   0.135929      -0.277925         -0.239996
# 4      -0.894383   -0.848197   0.171127      -0.899350         -0.239996
# ...          ...         ...        ...            ...               ...
# 3607   -0.143504    0.200830  -0.932686      -0.899350         -0.239996
# 3608   -0.894383   -0.848197  -0.932686      -0.899350         -0.239996
# 3609   -0.162240    0.164863  -0.932686      -0.899350         -0.239996
# 3610   -0.155034    0.179849  -0.932686      -0.899350         -0.239996
# 3611   -0.894383   -0.848197  -0.932686      -0.899350         -0.239996
#
#       1cyc-corrI  1cyc-corrT
# 0      -0.277205   -0.184349
# 1      -1.790114   -0.184349
# 2      -0.277205   -0.184349
# 3      -0.277205   -0.184349
# 4      -1.033660   -0.184349
# ...          ...         ...
# 3607   -0.277205   -0.184349
# 3608   -0.277205   -0.184349
# 3609   -0.277205   -0.436954
# 3610   -0.277205   -0.184349
# 3611   -0.277205   -0.184349
#
# [3612 rows x 14 columns]

# %%
#データを入力(X)１２個、出力(Y)１個に分ける
#CurrFB, VoltFBのうちCurrFBだけ除外してみる。
input_data = dataset_std.iloc[:, 2:14].values
output_data = dataset_std.iloc[:, 0:1].values
print( 'input_data=[', input_data.shape[0], ',', input_data.shape[1], ']')
print( 'output_data=[', output_data.shape[0], ',', output_data.shape[1],']')
# Out:
# input_data=[ 3612 , 12 ]
# output_data=[ 3612 , 1 ]

# %%
Xdata=[]
Ydata=[]
#LSTM用にデータ加工
#入力データの時間：10x6ms 60ms間の傾向
look_back=1
number = int( output_data.shape[0] / look_back ) - 1
print('Number=',number)
for i in range(number):
    Xtimedata=[]
    data_head = i * look_back
    for j in range(input_data.shape[1]):
        Xtimedata.append(input_data[data_head:data_head+look_back,j])
    Xtimedata=np.array(Xtimedata)
    Xtimedata=Xtimedata.transpose()
    Xdata.append(Xtimedata)
    Ytimedata=[]
    sum=0
    for j in range(look_back):
        sum += output_data[data_head+j,0]
    Ytimedata.append(sum/look_back)
    Ydata.append(Ytimedata)
# Out:
# Number= 3611

# %%
Xdata=np.array(Xdata)
Ydata=np.array(Ydata)

print(Xdata.shape)
#print(Xdata)
print(Ydata.shape)
#print(Ydata)
# Out:
# (3611, 1, 12)
# (3611, 1)

# %%
#ライブラリインポート
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.optimizers import Adam

# %%
input_data.shape[0]
# Out:
# 3612

# %%
#学習用の情報指定
Xdim=Xdata.shape[2]
Ydim=Ydata.shape[1]
validation_split_rate=0.2
print('Xdim=',Xdim,', Ydim=',Ydim,', validation_split_rate=',validation_split_rate)
# Out:
# Xdim= 12 , Ydim= 1 , validation_split_rate= 0.2

# %%
#モデル構築
#LSTMレイヤを多層化して複雑な表現ができるようにする。
#LSTM(34,...の34はユニット数でより複雑で長期的な傾向を理解するためにはユニット数をある程度の大きさにする。

model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(look_back,Xdim)))
model.add(LSTM(50, return_sequences=True))
model.add(LSTM(50))
model.add(Dense(Ydim))
model.compile(loss="mean_squared_error", optimizer=Adam(learning_rate=0.001))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 1, 50)             12600
#
#  lstm_1 (LSTM)               (None, 1, 50)             20200
#
#  lstm_2 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 53,051
# Trainable params: 53,051
# Non-trainable params: 0
# _________________________________________________________________

# %%
#学習開始
history=model.fit(Xdata,Ydata,batch_size=16,epochs=250,validation_split=validation_split_rate)
# Out:
# Epoch 1/250
# 181/181 [==============================] - 8s 12ms/step - loss: 0.3171 - val_loss: 0.1112
# Epoch 2/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0801 - val_loss: 0.0890
# Epoch 3/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0722 - val_loss: 0.0846
# Epoch 4/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0701 - val_loss: 0.0822
# Epoch 5/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0670 - val_loss: 0.0883
# Epoch 6/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0657 - val_loss: 0.0785
# Epoch 7/250
# 181/181 [==============================] - 1s 5ms/step - loss: 0.0667 - val_loss: 0.0852
# Epoch 8/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0625 - val_loss: 0.0759
# Epoch 9/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0659 - val_loss: 0.0777
# Epoch 10/250
# 181/181 [==============================] - 1s 5ms/step - loss: 0.0621 - val_loss: 0.0757
# Epoch 11/250
# 181/181 [==============================] - 1s 5ms/step - loss: 0.0651 - val_loss: 0.0760
# Epoch 12/250
# 181/181 [==============================] - 1s 5ms/step - loss: 0.0641 - val_loss: 0.1086
# Epoch 13/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0668 - val_loss: 0.0810
# Epoch 14/250
# 181/181 [==============================] - 1s 5ms/step - loss: 0.0650 - val_loss: 0.1118
# Epoch 15/250
# 181/181 [==============================] - 1s 5ms/step - loss: 0.0626 - val_loss: 0.0756
# Epoch 16/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0619 - val_loss: 0.0870
# Epoch 17/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0646 - val_loss: 0.0886
# Epoch 18/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0602 - val_loss: 0.0786
# Epoch 19/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0640 - val_loss: 0.0825
# Epoch 20/250
# 181/181 [==============================] - 1s 5ms/step - loss: 0.0609 - val_loss: 0.0879
# Epoch 21/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0611 - val_loss: 0.0896
# Epoch 22/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0591 - val_loss: 0.0859
# Epoch 23/250
# 181/181 [==============================] - 1s 5ms/step - loss: 0.0584 - val_loss: 0.0867
# Epoch 24/250
# 181/181 [==============================] - 1s 5ms/step - loss: 0.0634 - val_loss: 0.0836
# Epoch 25/250
# 181/181 [==============================] - 1s 5ms/step - loss: 0.0594 - val_loss: 0.0829
# Epoch 26/250
# 181/181 [==============================] - 1s 5ms/step - loss: 0.0585 - val_loss: 0.0856
# Epoch 27/250
# 181/181 [==============================] - 1s 5ms/step - loss: 0.0575 - val_loss: 0.1279
# Epoch 28/250
# 181/181 [==============================] - 1s 5ms/step - loss: 0.0625 - val_loss: 0.0878
# Epoch 29/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0599 - val_loss: 0.0914
# Epoch 30/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0581 - val_loss: 0.0797
# Epoch 31/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0594 - val_loss: 0.0937
# Epoch 32/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0605 - val_loss: 0.0780
# Epoch 33/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0566 - val_loss: 0.0908
# Epoch 34/250
# 181/181 [==============================] - 1s 5ms/step - loss: 0.0599 - val_loss: 0.0841
# Epoch 35/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0579 - val_loss: 0.0752
# Epoch 36/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0566 - val_loss: 0.0749
# Epoch 37/250
# 181/181 [==============================] - 1s 5ms/step - loss: 0.0553 - val_loss: 0.1570
# Epoch 38/250
# 181/181 [==============================] - 1s 5ms/step - loss: 0.0560 - val_loss: 0.0857
# Epoch 39/250
# 181/181 [==============================] - 1s 5ms/step - loss: 0.0557 - val_loss: 0.0900
# Epoch 40/250
# 181/181 [==============================] - 1s 5ms/step - loss: 0.0558 - val_loss: 0.1106
# Epoch 41/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0553 - val_loss: 0.1036
# Epoch 42/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0564 - val_loss: 0.1158
# Epoch 43/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0574 - val_loss: 0.0791
# Epoch 44/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0596 - val_loss: 0.0815
# Epoch 45/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0554 - val_loss: 0.0923
# Epoch 46/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0554 - val_loss: 0.0783
# Epoch 47/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0531 - val_loss: 0.0855
# Epoch 48/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0529 - val_loss: 0.0833
# Epoch 49/250
# 181/181 [==============================] - 1s 5ms/step - loss: 0.0526 - val_loss: 0.1008
# Epoch 50/250
# 181/181 [==============================] - 1s 5ms/step - loss: 0.0544 - val_loss: 0.0881
# Epoch 51/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0537 - val_loss: 0.0812
# Epoch 52/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0539 - val_loss: 0.0843
# Epoch 53/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0535 - val_loss: 0.1018
# Epoch 54/250
# 181/181 [==============================] - 1s 5ms/step - loss: 0.0510 - val_loss: 0.0806
# Epoch 55/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0514 - val_loss: 0.0805
# Epoch 56/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0564 - val_loss: 0.0846
# Epoch 57/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0509 - val_loss: 0.0893
# Epoch 58/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0508 - val_loss: 0.0736
# Epoch 59/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0493 - val_loss: 0.0788
# Epoch 60/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0513 - val_loss: 0.0822
# Epoch 61/250
# 181/181 [==============================] - 1s 5ms/step - loss: 0.0498 - val_loss: 0.0920
# Epoch 62/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0488 - val_loss: 0.1421
# Epoch 63/250
# 181/181 [==============================] - 1s 5ms/step - loss: 0.0490 - val_loss: 0.0781
# Epoch 64/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0494 - val_loss: 0.0840
# Epoch 65/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0481 - val_loss: 0.0891
# Epoch 66/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0472 - val_loss: 0.0889
# Epoch 67/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0487 - val_loss: 0.0795
# Epoch 68/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0485 - val_loss: 0.1114
# Epoch 69/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0495 - val_loss: 0.0832
# Epoch 70/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0466 - val_loss: 0.0889
# Epoch 71/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0465 - val_loss: 0.1023
# Epoch 72/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0483 - val_loss: 0.0866
# Epoch 73/250
# 181/181 [==============================] - 1s 5ms/step - loss: 0.0467 - val_loss: 0.1019
# Epoch 74/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0466 - val_loss: 0.0799
# Epoch 75/250
# 181/181 [==============================] - 1s 5ms/step - loss: 0.0466 - val_loss: 0.0880
# Epoch 76/250
# 181/181 [==============================] - 1s 5ms/step - loss: 0.0460 - val_loss: 0.0883
# Epoch 77/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0448 - val_loss: 0.0922
# Epoch 78/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0453 - val_loss: 0.0871
# Epoch 79/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0449 - val_loss: 0.0991
# Epoch 80/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0441 - val_loss: 0.1064
# Epoch 81/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0455 - val_loss: 0.0915
# Epoch 82/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0449 - val_loss: 0.0851
# Epoch 83/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0438 - val_loss: 0.1051
# Epoch 84/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0443 - val_loss: 0.0959
# Epoch 85/250
# 181/181 [==============================] - 1s 5ms/step - loss: 0.0459 - val_loss: 0.1292
# Epoch 86/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0437 - val_loss: 0.0909
# Epoch 87/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0440 - val_loss: 0.0906
# Epoch 88/250
# 181/181 [==============================] - 1s 5ms/step - loss: 0.0430 - val_loss: 0.1125
# Epoch 89/250
# 181/181 [==============================] - 1s 5ms/step - loss: 0.0461 - val_loss: 0.0924
# Epoch 90/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0440 - val_loss: 0.0881
# Epoch 91/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0415 - val_loss: 0.0861
# Epoch 92/250
# 181/181 [==============================] - 1s 5ms/step - loss: 0.0440 - val_loss: 0.0866
# Epoch 93/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0440 - val_loss: 0.0899
# Epoch 94/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0426 - val_loss: 0.0970
# Epoch 95/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0422 - val_loss: 0.0862
# Epoch 96/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0431 - val_loss: 0.0871
# Epoch 97/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0456 - val_loss: 0.0891
# Epoch 98/250
# 181/181 [==============================] - 1s 5ms/step - loss: 0.0423 - val_loss: 0.0947
# Epoch 99/250
# 181/181 [==============================] - 1s 5ms/step - loss: 0.0418 - val_loss: 0.1042
# Epoch 100/250
# 181/181 [==============================] - 1s 5ms/step - loss: 0.0416 - val_loss: 0.0867
# Epoch 101/250
# 181/181 [==============================] - 1s 5ms/step - loss: 0.0414 - val_loss: 0.1045
# Epoch 102/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0436 - val_loss: 0.0918
# Epoch 103/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0410 - val_loss: 0.1173
# Epoch 104/250
# 181/181 [==============================] - 1s 5ms/step - loss: 0.0424 - val_loss: 0.0930
# Epoch 105/250
# 181/181 [==============================] - 1s 5ms/step - loss: 0.0430 - val_loss: 0.0993
# Epoch 106/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0451 - val_loss: 0.0945
# Epoch 107/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0407 - val_loss: 0.1077
# Epoch 108/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0419 - val_loss: 0.1014
# Epoch 109/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0412 - val_loss: 0.1037
# Epoch 110/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0419 - val_loss: 0.0982
# Epoch 111/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0415 - val_loss: 0.0993
# Epoch 112/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0403 - val_loss: 0.0964
# Epoch 113/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0431 - val_loss: 0.0986
# Epoch 114/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0428 - val_loss: 0.1072
# Epoch 115/250
# 181/181 [==============================] - 1s 5ms/step - loss: 0.0400 - val_loss: 0.1003
# Epoch 116/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0392 - val_loss: 0.0973
# Epoch 117/250
# 181/181 [==============================] - 1s 5ms/step - loss: 0.0414 - val_loss: 0.1064
# Epoch 118/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0415 - val_loss: 0.1044
# Epoch 119/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0407 - val_loss: 0.0947
# Epoch 120/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0454 - val_loss: 0.1004
# Epoch 121/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0417 - val_loss: 0.0940
# Epoch 122/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0393 - val_loss: 0.1137
# Epoch 123/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0383 - val_loss: 0.1051
# Epoch 124/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0374 - val_loss: 0.1045
# Epoch 125/250
# 181/181 [==============================] - 1s 5ms/step - loss: 0.0393 - val_loss: 0.1187
# Epoch 126/250
# 181/181 [==============================] - 1s 5ms/step - loss: 0.0382 - val_loss: 0.1471
# Epoch 127/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0395 - val_loss: 0.1014
# Epoch 128/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0372 - val_loss: 0.1392
# Epoch 129/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0387 - val_loss: 0.1234
# Epoch 130/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0401 - val_loss: 0.1070
# Epoch 131/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0424 - val_loss: 0.1118
# Epoch 132/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0379 - val_loss: 0.1130
# Epoch 133/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0377 - val_loss: 0.1281
# Epoch 134/250
# 181/181 [==============================] - 2s 8ms/step - loss: 0.0403 - val_loss: 0.1061
# Epoch 135/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0372 - val_loss: 0.1297
# Epoch 136/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0373 - val_loss: 0.0999
# Epoch 137/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0370 - val_loss: 0.1082
# Epoch 138/250
# 181/181 [==============================] - 1s 5ms/step - loss: 0.0377 - val_loss: 0.1093
# Epoch 139/250
# 181/181 [==============================] - 1s 5ms/step - loss: 0.0369 - val_loss: 0.1073
# Epoch 140/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0430 - val_loss: 0.1074
# Epoch 141/250
# 181/181 [==============================] - 1s 5ms/step - loss: 0.0358 - val_loss: 0.1114
# Epoch 142/250
# 181/181 [==============================] - 1s 5ms/step - loss: 0.0371 - val_loss: 0.1031
# Epoch 143/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0364 - val_loss: 0.1206
# Epoch 144/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0356 - val_loss: 0.1162
# Epoch 145/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0360 - val_loss: 0.1231
# Epoch 146/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0365 - val_loss: 0.1271
# Epoch 147/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0352 - val_loss: 0.0989
# Epoch 148/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0371 - val_loss: 0.1136
# Epoch 149/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0370 - val_loss: 0.1182
# Epoch 150/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0361 - val_loss: 0.1249
# Epoch 151/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0375 - val_loss: 0.1311
# Epoch 152/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0366 - val_loss: 0.1085
# Epoch 153/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0360 - val_loss: 0.1271
# Epoch 154/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0348 - val_loss: 0.1148
# Epoch 155/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0340 - val_loss: 0.1271
# Epoch 156/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0360 - val_loss: 0.1190
# Epoch 157/250
# 181/181 [==============================] - 1s 5ms/step - loss: 0.0346 - val_loss: 0.1393
# Epoch 158/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0389 - val_loss: 0.1108
# Epoch 159/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0335 - val_loss: 0.1513
# Epoch 160/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0340 - val_loss: 0.1094
# Epoch 161/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0363 - val_loss: 0.1278
# Epoch 162/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0350 - val_loss: 0.1086
# Epoch 163/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0338 - val_loss: 0.1106
# Epoch 164/250
# 181/181 [==============================] - 1s 5ms/step - loss: 0.0335 - val_loss: 0.1333
# Epoch 165/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0343 - val_loss: 0.1136
# Epoch 166/250
# 181/181 [==============================] - 1s 5ms/step - loss: 0.0335 - val_loss: 0.1187
# Epoch 167/250
# 181/181 [==============================] - 1s 5ms/step - loss: 0.0347 - val_loss: 0.1085
# Epoch 168/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0339 - val_loss: 0.1030
# Epoch 169/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0355 - val_loss: 0.1195
# Epoch 170/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0328 - val_loss: 0.1105
# Epoch 171/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0337 - val_loss: 0.1153
# Epoch 172/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0329 - val_loss: 0.1157
# Epoch 173/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0336 - val_loss: 0.1165
# Epoch 174/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0338 - val_loss: 0.1214
# Epoch 175/250
# 181/181 [==============================] - 1s 5ms/step - loss: 0.0326 - val_loss: 0.1226
# Epoch 176/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0328 - val_loss: 0.1165
# Epoch 177/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0319 - val_loss: 0.1100
# Epoch 178/250
# 181/181 [==============================] - 1s 5ms/step - loss: 0.0335 - val_loss: 0.1303
# Epoch 179/250
# 181/181 [==============================] - 1s 5ms/step - loss: 0.0333 - val_loss: 0.1184
# Epoch 180/250
# 181/181 [==============================] - 1s 5ms/step - loss: 0.0324 - val_loss: 0.1199
# Epoch 181/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0324 - val_loss: 0.1308
# Epoch 182/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0342 - val_loss: 0.1272
# Epoch 183/250
# 181/181 [==============================] - 1s 5ms/step - loss: 0.0343 - val_loss: 0.1199
# Epoch 184/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0313 - val_loss: 0.1210
# Epoch 185/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0324 - val_loss: 0.1208
# Epoch 186/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0313 - val_loss: 0.1205
# Epoch 187/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0312 - val_loss: 0.1161
# Epoch 188/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0334 - val_loss: 0.1131
# Epoch 189/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0315 - val_loss: 0.1216
# Epoch 190/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0317 - val_loss: 0.1214
# Epoch 191/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0317 - val_loss: 0.1232
# Epoch 192/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0324 - val_loss: 0.1303
# Epoch 193/250
# 181/181 [==============================] - 1s 5ms/step - loss: 0.0332 - val_loss: 0.1161
# Epoch 194/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0307 - val_loss: 0.1296
# Epoch 195/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0309 - val_loss: 0.1295
# Epoch 196/250
# 181/181 [==============================] - 1s 5ms/step - loss: 0.0326 - val_loss: 0.1268
# Epoch 197/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0337 - val_loss: 0.1216
# Epoch 198/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0300 - val_loss: 0.1212
# Epoch 199/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0308 - val_loss: 0.1187
# Epoch 200/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0300 - val_loss: 0.1179
# Epoch 201/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0297 - val_loss: 0.1197
# Epoch 202/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0297 - val_loss: 0.1218
# Epoch 203/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0307 - val_loss: 0.1246
# Epoch 204/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0342 - val_loss: 0.1162
# Epoch 205/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0305 - val_loss: 0.1165
# Epoch 206/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0302 - val_loss: 0.1142
# Epoch 207/250
# 181/181 [==============================] - 1s 5ms/step - loss: 0.0303 - val_loss: 0.1221
# Epoch 208/250
# 181/181 [==============================] - 1s 5ms/step - loss: 0.0303 - val_loss: 0.1129
# Epoch 209/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0301 - val_loss: 0.1147
# Epoch 210/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0297 - val_loss: 0.1251
# Epoch 211/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0291 - val_loss: 0.1229
# Epoch 212/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0287 - val_loss: 0.1229
# Epoch 213/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0290 - val_loss: 0.1202
# Epoch 214/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0294 - val_loss: 0.1252
# Epoch 215/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0287 - val_loss: 0.1310
# Epoch 216/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0290 - val_loss: 0.1202
# Epoch 217/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0303 - val_loss: 0.1234
# Epoch 218/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0284 - val_loss: 0.1279
# Epoch 219/250
# 181/181 [==============================] - 1s 5ms/step - loss: 0.0298 - val_loss: 0.1207
# Epoch 220/250
# 181/181 [==============================] - 1s 5ms/step - loss: 0.0294 - val_loss: 0.1183
# Epoch 221/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0296 - val_loss: 0.1228
# Epoch 222/250
# 181/181 [==============================] - 1s 5ms/step - loss: 0.0287 - val_loss: 0.1226
# Epoch 223/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0284 - val_loss: 0.1223
# Epoch 224/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0283 - val_loss: 0.1304
# Epoch 225/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0287 - val_loss: 0.1149
# Epoch 226/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0281 - val_loss: 0.1280
# Epoch 227/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0286 - val_loss: 0.1182
# Epoch 228/250
# 181/181 [==============================] - 1s 5ms/step - loss: 0.0284 - val_loss: 0.1235
# Epoch 229/250
# 181/181 [==============================] - 1s 5ms/step - loss: 0.0283 - val_loss: 0.1223
# Epoch 230/250
# 181/181 [==============================] - 1s 5ms/step - loss: 0.0289 - val_loss: 0.1232
# Epoch 231/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0275 - val_loss: 0.1281
# Epoch 232/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0269 - val_loss: 0.1198
# Epoch 233/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0280 - val_loss: 0.1277
# Epoch 234/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0276 - val_loss: 0.1268
# Epoch 235/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0278 - val_loss: 0.1276
# Epoch 236/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0270 - val_loss: 0.1265
# Epoch 237/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0278 - val_loss: 0.1261
# Epoch 238/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0278 - val_loss: 0.1238
# Epoch 239/250
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0266 - val_loss: 0.1273
# Epoch 240/250
# 181/181 [==============================] - 1s 5ms/step - loss: 0.0267 - val_loss: 0.1275
# Epoch 241/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0278 - val_loss: 0.1237
# Epoch 242/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0273 - val_loss: 0.1219
# Epoch 243/250
# 181/181 [==============================] - 1s 5ms/step - loss: 0.0272 - val_loss: 0.1312
# Epoch 244/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0277 - val_loss: 0.1270
# Epoch 245/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0261 - val_loss: 0.1269
# Epoch 246/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0264 - val_loss: 0.1234
# Epoch 247/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0258 - val_loss: 0.1236
# Epoch 248/250
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0265 - val_loss: 0.1351
# Epoch 249/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0265 - val_loss: 0.1172
# Epoch 250/250
# 181/181 [==============================] - 1s 8ms/step - loss: 0.0255 - val_loss: 0.1212

# %%
#学習履歴のグラフ化
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
#学習データから学習時にテストデータとして用いた部分を取り出す
Xdata_validation=Xdata[-int(len(Xdata)*(validation_split_rate)):]
Ydata_validation=Ydata[-int(len(Ydata)*(validation_split_rate)):]

# %%
#テスト
Predictdata = model.predict(Xdata_validation)
#テスト結果のグラフ化
plt.plot(range(0, len(Predictdata)),Predictdata[:,0], color="b", label="predict")
plt.plot(range(0, len(Ydata_validation)),Ydata_validation[:,0], color="r", label="row_data")
plt.legend()
plt.show()
# Out:
# 23/23 [==============================] - 1s 2ms/step

# %%
import pandas as pd
predict_df = pd.DataFrame(Predictdata, columns=["predict"])
validation_df = pd.DataFrame(Ydata_validation, columns=["row_data"])
predict_df.to_csv("/content/drive/MyDrive/Colab Notebooks/LSTM_try04-7_RENEW_Alldata_prediction.csv", index=False)
validation_df.to_csv("/content/drive/MyDrive/Colab Notebooks/LSTM_try04-7_RENEW_Alldata_validation.csv", index=False)
